# %%
def calculator():
    print("Simple Calculator")
    print("Operations: +, -, *, /")
    
    try:
        num1 = float(input("Enter first number: "))
        operator = input("Enter operator (+, -, *, /): ")
        num2 = float(input("Enter second number: "))

        if operator == "+":
            result = num1 + num2
        elif operator == "-":
            result = num1 - num2
        elif operator == "*":
            result = num1 * num2
        elif operator == "/":
            if num2 == 0:
                print("Error: Division by zero!")
                return
            result = num1 / num2
        else:
            print("Invalid operator!")
            return

        print(f"Result: {result}")

    except ValueError:
        print("Invalid input! Please enter numbers.")

calculator()
# Out:
# Simple Calculator
# Operations: +, -, *, /
# Invalid operator!

# %%
a = ["thsi is abc hell owoeorjlsajf"]
for i in a:
    print(i)
# Out:
# thsi is abc hell owoeorjlsajf

# %%
f = "hello"
print(f)
# Out:
# hello

# %%
for i in range(0, 10):
    print(i)

# %%
while True:
    print("aibek")
